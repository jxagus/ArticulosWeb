-- %% [markdown]
-- # [dbo].[ARTICULOS]

-- %%
USE [CATALOGO_WEB_DB]
GO

-- %%
/****** Object:  Table [dbo].[ARTICULOS]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ARTICULOS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Codigo] [varchar](50) NULL,
	[Nombre] [varchar](50) NULL,
	[Descripcion] [varchar](150) NULL,
	[IdMarca] [int] NULL,
	[IdCategoria] [int] NULL,
	[ImagenUrl] [varchar](1000) NULL,
	[Precio] [money] NULL,
 CONSTRAINT [PK_ARTICULOS] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CATEGORIAS]

-- %%
/****** Object:  Table [dbo].[CATEGORIAS]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CATEGORIAS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [varchar](50) NULL,
 CONSTRAINT [PK_CATEGORIAS] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FAVORITOS]

-- %%
/****** Object:  Table [dbo].[FAVORITOS]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FAVORITOS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdUser] [int] NOT NULL,
	[IdArticulo] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MARCAS]

-- %%
/****** Object:  Table [dbo].[MARCAS]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MARCAS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [varchar](50) NULL,
 CONSTRAINT [PK_MARCAS] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USERS]

-- %%
/****** Object:  Table [dbo].[USERS]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USERS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[email] [varchar](100) NOT NULL,
	[pass] [varchar](20) NOT NULL,
	[nombre] [varchar](50) NULL,
	[apellido] [varchar](50) NULL,
	[urlImagenPerfil] [varchar](500) NULL,
	[admin] [bit] NOT NULL,
	[fechaNacimiento] [date] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__USERS__admin__3C69FB99]

-- %%
ALTER TABLE [dbo].[USERS] ADD  DEFAULT ((0)) FOR [admin]
GO

-- %% [markdown]
-- # [dbo].[insertarNuevo]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarNuevo]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[insertarNuevo]
@email varchar(50),
@pass varchar(50)
as
insert into USERS (email,pass, admin)output inserted.Id values (@email,@pass, 0)
GO

-- %% [markdown]
-- # [dbo].[storedAltaArticulo]

-- %%
/****** Object:  StoredProcedure [dbo].[storedAltaArticulo]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[storedAltaArticulo]
@Codigo varchar(50),
@Nombre varchar(50),
@Descripcion varchar(150),
@IdMarca int,
@IdCategoria int,
@ImagenUrl varchar(1000),
@Precio money
as
insert into ARTICULOS values (@Codigo, @Nombre, @Descripcion, @IdMarca, @IdCategoria, @ImagenUrl, @Precio)
GO

-- %% [markdown]
-- # [dbo].[storedListar]

-- %%
/****** Object:  StoredProcedure [dbo].[storedListar]    Script Date: 31/5/2025 11:48:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[storedListar] as
SELECT A.Id, A.Codigo, A.Nombre, A.Descripcion, C.Descripcion AS Tipo, M.Descripcion AS Marcas, A.Precio, A.ImagenUrl, A.IdCategoria, A.IdMarca 
FROM ARTICULOS A, CATEGORIAS C, MARCAS M 
WHERE A.IdCategoria = C.Id AND A.IdMarca = M.Id 
GO
